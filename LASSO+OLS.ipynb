# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
ptb_data = pd.read_csv('ptb_data.csv')

# %%
sample_df = ptb_data.sample(frac=0.1)

# %%
# df_encoded = ptb_data.drop(columns = ['PTB Defence','Anonymize 1PlayerId', 'EventName', 'Club Id', 'Opposition Id', 'PTB Contest', 
#                                         'PTB Ultimate Outcome', 'WeatherConditionName'])


df_encoded = ptb_data.drop(columns = ['PTB Defence', 'Anonymize 1PlayerId', 'Player Id', 'ZonePhysical'])

df_encoded = pd.get_dummies(df_encoded, columns=['WeatherConditionName', 'Club Id', 'Opposition Id', 'PTB Contest', 'EventName', 'PTB Ultimate Outcome', 'OfficialId'], drop_first=True)


df_encoded = df_encoded.dropna()

df_encoded[df_encoded.select_dtypes(include=['bool']).columns] = df_encoded.select_dtypes(include=['bool']).astype(int)

df_encoded.info()

df_encoded.to_csv('encoded_ptb_data.csv', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 111990 entries, 0 to 112026
# Data columns (total 91 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   Away Score                                         111990 non-null  int64
#  1   DurationSecs                                       111990 non-null  float64
#  2   Half                                               111990 non-null  int64
#  3   Home Score                                         111990 non-null  int64
#  4   MatchId                                            111990 non-null  int64
#  5   OppPossessionSecs                                  111990 non-null  float64
#  6   OppScore                                           111990 non-null  float64
#  7   PositionId                                         111990 non-null  float64
#  8   PossessionSecs                                     111990 non-null  float64
#  9   PTB Tackle Result                                  111990 non-null  int64
#  10  Set Type                                           111990 non-null  int64
#  11  Total Involved Tacklers                            111990 non-null  float64
#  12  Raw Tackle Number                                  111990 non-null  float64
#  13  RoundId                                            111990 non-null  int64
#  14  RunOn                                              111990 non-null  int64
#  15  Score                                              111990 non-null  float64
#  16  SeasonId                                           111990 non-null  int64
#  17  SeqNumber                                          111990 non-null  int64
#  18  Set                                                111990 non-null  int64
#  19  Tackle                                             111990 non-null  int64
#  20  TotalPossessionSecs                                111990 non-null  float64
#  21  ZonePossession                                     111990 non-null  int64
#  22  GameTime                                           111990 non-null  float64
#  23  ElapsedTime                                        111990 non-null  float64
#  24  IsHome                                             111990 non-null  int64
#  25  CurrentMargin                                      111990 non-null  float64
#  26  WeatherConditionName_Rain                          111990 non-null  int32
#  27  WeatherConditionName_Showers                       111990 non-null  int32
#  28  WeatherConditionName_Snow                          111990 non-null  int32
#  29  WeatherConditionName_Unknown                       111990 non-null  int32
#  30  Club Id_1d6cd83892ee4afdcd8ccd94f817b4a6           111990 non-null  int32
#  31  Club Id_1d6cd83892ee4afdcd8ccd94f81ftnjhl3s        111990 non-null  int32
#  32  Club Id_367ef61d2bc259e608027a8d349c933e           111990 non-null  int32
#  33  Club Id_3b26834df063f9d51de216a07ec36929           111990 non-null  int32
#  34  Club Id_58485e3acf60682c8fc37d9d521b3019           111990 non-null  int32
#  35  Club Id_5e03a19f4d014a2220665cfd56522d35           111990 non-null  int32
#  36  Club Id_837e03d56b4dba3b8a4a5425c0420abd           111990 non-null  int32
#  37  Club Id_980c9c368ae4f1129ea0a6fdd711fa8f           111990 non-null  int32
#  38  Club Id_a73752d38e4a78e3e14917f5435ffb6d           111990 non-null  int32
#  83  OfficialId_500042                                  111990 non-null  int32
#  84  OfficialId_500045                                  111990 non-null  int32
#  85  OfficialId_500050                                  111990 non-null  int32
#  86  OfficialId_500067                                  111990 non-null  int32
#  87  OfficialId_500070                                  111990 non-null  int32
#  88  OfficialId_500072                                  111990 non-null  int32
#  89  OfficialId_500075                                  111990 non-null  int32
#  90  OfficialId_500117                                  111990 non-null  int32
# dtypes: float64(12), int32(65), int64(14)
# memory usage: 50.8 MB

# %%
import statsmodels.api as sm

Y = df_encoded['DurationSecs']
X = df_encoded.drop(['DurationSecs'],axis = 1)
X = sm.add_constant(X)

# %%
model = sm.OLS(Y, X)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           DurationSecs   R-squared:                       0.173
# Model:                            OLS   Adj. R-squared:                  0.173
# Method:                 Least Squares   F-statistic:                     809.6
# Date:                Sun, 03 Nov 2024   Prob (F-statistic):               0.00
# Time:                        11:15:48   Log-Likelihood:            -1.5723e+05
# No. Observations:              111990   AIC:                         3.145e+05
# Df Residuals:                  111960   BIC:                         3.148e+05
# Df Model:                          29
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                         8.054e-07   2.54e-08     31.730      0.000    7.56e-07    8.55e-07
# Away Score                       0.0020      0.000      6.775      0.000       0.001       0.003
# Half                             0.1487      0.057      2.623      0.009       0.038       0.260
# Home Score                       0.0021      0.000      7.182      0.000       0.002       0.003
# MatchId                       4.539e-08   3.16e-09     14.379      0.000    3.92e-08    5.16e-08
# OfficialId                   -1.786e-07   2.97e-08     -6.008      0.000   -2.37e-07    -1.2e-07
# OppPossessionSecs             6.357e-05    2.8e-05      2.267      0.023    8.61e-06       0.000
# OppScore                        -0.0021      0.001     -3.938      0.000      -0.003      -0.001
# Player Id                     2.159e-10   1.39e-10      1.556      0.120   -5.61e-11    4.88e-10
# PositionId                      -0.0107      0.001    -12.228      0.000      -0.012      -0.009
# PossessionSecs                   0.0002    2.8e-05      8.399      0.000       0.000       0.000
# PTB Tackle Result               -0.7713      0.006   -127.681      0.000      -0.783      -0.759
# Set Type                         0.1912      0.012     16.033      0.000       0.168       0.215
# Total Involved Tacklers          0.0325      0.004      7.786      0.000       0.024       0.041
# Raw Tackle Number               -0.0321      0.009     -3.684      0.000      -0.049      -0.015
# RoundId                         -0.0015      0.000     -3.333      0.001      -0.002      -0.001
# RunOn                            0.0424      0.010      4.213      0.000       0.023       0.062
# Score                            0.0001      0.001      0.272      0.786      -0.001       0.001
# SeasonId                         0.0016   5.08e-05     31.703      0.000       0.002       0.002
# SeqNumber                       -0.0001   1.35e-05     -8.238      0.000      -0.000   -8.49e-05
# Set                             -0.0010      0.001     -0.919      0.358      -0.003       0.001
# Tackle                          -0.0608      0.008     -7.362      0.000      -0.077      -0.045
# TotalPossessionSecs              0.0003   3.53e-05      8.459      0.000       0.000       0.000
# ZonePhysical                  4.551e-05      0.000      0.292      0.770      -0.000       0.000
# ZonePossession                   0.0034      0.000     11.247      0.000       0.003       0.004
# GameTime                         0.0022      0.002      0.944      0.345      -0.002       0.007
# ElapsedTime                      0.0034      0.002      2.042      0.041       0.000       0.007
# IsHome                          -0.0423      0.006     -7.031      0.000      -0.054      -0.031
# CurrentMargin                    0.0022      0.000     10.744      0.000       0.002       0.003
# WeatherConditionName_Rain        0.0788      0.021      3.709      0.000       0.037       0.120
# WeatherConditionName_Showers     0.0084      0.021      0.407      0.684      -0.032       0.049
# WeatherConditionName_Snow       -0.0728      0.042     -1.741      0.082      -0.155       0.009
# WeatherConditionName_Unknown     0.0580      0.008      7.361      0.000       0.043       0.073
# ==============================================================================
# Omnibus:                    15524.754   Durbin-Watson:                   1.840
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            94737.204
# Skew:                           0.520   Prob(JB):                         0.00
# Kurtosis:                       7.384   Cond. No.                     2.19e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.42e-13. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
from sklearn.linear_model import LassoCV, Lasso
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

y = df_encoded['DurationSecs']
X = df_encoded.drop(['DurationSecs'],axis = 1)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=99)

lasso_cv = LassoCV(cv=5, max_iter=100000).fit(X_train, y_train)
print("Optimal alpha:", lasso_cv.alpha_)

lasso_best = Lasso(alpha=lasso_cv.alpha_)
lasso_best.fit(X_train, y_train)


y_pred = lasso_best.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error: {mae}")


mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}" )


r_squared = r2_score(y_test, y_pred)
print(f"R-squared: {r_squared}")
n = X_test.shape[0]  # Number of observations
p = X_test.shape[1]  # Number of features (predictors)
adjusted_r_squared = 1 - (1 - r_squared) * (n - 1) / (n - p - 1)
print(f"Adjusted_r_squared: {adjusted_r_squared}")

pd.set_option('display.max_rows', None)

lasso_coefficients = pd.Series(lasso_best.coef_, index=X.columns)
print(lasso_coefficients)
# Out:
# Optimal alpha: 0.0006610074504539635
# Mean Absolute Error: 0.5450026483202601
# Mean Squared Error: 0.46016071926547153
# R-squared: 0.5958406266031282
# Adjusted_r_squared: 0.5942100019738317
# Away Score                                           0.006216
# Half                                                 0.000000
# Home Score                                           0.012281
# MatchId                                              0.021525
# OppPossessionSecs                                    0.000000
# OppScore                                            -0.000000
# PositionId                                          -0.021226
# PossessionSecs                                       0.031061
# PTB Tackle Result                                   -0.215594
# Set Type                                             0.043432
# Total Involved Tacklers                              0.041862
# Raw Tackle Number                                   -0.050469
# RoundId                                             -0.010002
# RunOn                                                0.007860
# Score                                                0.007222
# SeasonId                                             0.017606
# SeqNumber                                           -0.000000
# Set                                                 -0.000000
# Tackle                                              -0.026285
# TotalPossessionSecs                                  0.000000
# ZonePossession                                       0.035085
# GameTime                                             0.011266
# ElapsedTime                                          0.000000
# IsHome                                              -0.012330
# CurrentMargin                                        0.007659
# WeatherConditionName_Rain                            0.009232
# WeatherConditionName_Showers                        -0.000938
# WeatherConditionName_Snow                           -0.000128
# WeatherConditionName_Unknown                         0.010984
# Club Id_1d6cd83892ee4afdcd8ccd94f817b4a6             0.004915
# Club Id_1d6cd83892ee4afdcd8ccd94f81ftnjhl3s         -0.005827
# Club Id_367ef61d2bc259e608027a8d349c933e            -0.017812
# Club Id_3b26834df063f9d51de216a07ec36929             0.012867
# Club Id_58485e3acf60682c8fc37d9d521b3019             0.009945
# Club Id_5e03a19f4d014a2220665cfd56522d35            -0.002313
# Club Id_837e03d56b4dba3b8a4a5425c0420abd            -0.000522
# Club Id_980c9c368ae4f1129ea0a6fdd711fa8f            -0.003607
