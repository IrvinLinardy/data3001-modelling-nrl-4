# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
ptb_data = pd.read_csv('ptb_data.csv')

# %%
sample_df = ptb_data.sample(frac=0.1)

# %%
# DATA SETUP

# ptb_data['currMargin_gameTime_interaction'] = ptb_data['CurrentMargin'] * ptb_data['GameTime']

df_encoded = ptb_data.drop(columns = ['PTB Defence', 'Anonymize 1PlayerId', 'Player Id', 'ZonePhysical', 'EventName', 'MatchId', 'Tackle', 'PositionId',
                                     'OppScore', 'Away Score', 'Home Score', 'PTB Tackle Result', 'TotalPossessionSecs', 'ElapsedTime', 'GameTime',
                                      'Set'])


df_encoded = pd.get_dummies(df_encoded, columns=['WeatherConditionName', 'Club Id', 'SeasonId', 'Opposition Id', 'Half', 'PTB Contest', 
                                                 'PTB Ultimate Outcome', 'OfficialId', 'Raw Tackle Number'], drop_first=True)


df_encoded = df_encoded.dropna()

df_encoded[df_encoded.select_dtypes(include=['bool']).columns] = df_encoded.select_dtypes(include=['bool']).astype(int)

df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 111991 entries, 0 to 112026
# Data columns (total 87 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   DurationSecs                                       111991 non-null  float64
#  1   OppPossessionSecs                                  111991 non-null  float64
#  2   PossessionSecs                                     111991 non-null  float64
#  3   Set Type                                           111991 non-null  int64
#  4   Total Involved Tacklers                            111991 non-null  float64
#  5   RoundId                                            111991 non-null  int64
#  6   RunOn                                              111991 non-null  int64
#  7   Score                                              111991 non-null  float64
#  8   SeqNumber                                          111991 non-null  int64
#  9   ZonePossession                                     111991 non-null  int64
#  10  IsHome                                             111991 non-null  int64
#  11  CurrentMargin                                      111991 non-null  float64
#  12  WeatherConditionName_Rain                          111991 non-null  int32
#  13  WeatherConditionName_Showers                       111991 non-null  int32
#  14  WeatherConditionName_Snow                          111991 non-null  int32
#  15  WeatherConditionName_Unknown                       111991 non-null  int32
#  16  Club Id_1d6cd83892ee4afdcd8ccd94f817b4a6           111991 non-null  int32
#  17  Club Id_1d6cd83892ee4afdcd8ccd94f81ftnjhl3s        111991 non-null  int32
#  18  Club Id_367ef61d2bc259e608027a8d349c933e           111991 non-null  int32
#  19  Club Id_3b26834df063f9d51de216a07ec36929           111991 non-null  int32
#  20  Club Id_58485e3acf60682c8fc37d9d521b3019           111991 non-null  int32
#  21  Club Id_5e03a19f4d014a2220665cfd56522d35           111991 non-null  int32
#  22  Club Id_837e03d56b4dba3b8a4a5425c0420abd           111991 non-null  int32
#  23  Club Id_980c9c368ae4f1129ea0a6fdd711fa8f           111991 non-null  int32
#  24  Club Id_a73752d38e4a78e3e14917f5435ffb6d           111991 non-null  int32
#  25  Club Id_b53920c88e4eebf2faa9f4fb43b8944a           111991 non-null  int32
#  26  Club Id_c03196722c1a837b39f79f1714db475d           111991 non-null  int32
#  27  Club Id_c14e0139ad91a9741a5731a596aa6549           111991 non-null  int32
#  28  Club Id_d3ac47d424b41fd738ec9500dbda2d59           111991 non-null  int32
#  29  Club Id_dc3c7bd8148814b7c4105841baa68e23           111991 non-null  int32
#  30  Club Id_f38f7f087f646c38c0207f1b2af32f12           111991 non-null  int32
#  31  Club Id_fdfcde48e2cbf12cc4710a2644b86d85           111991 non-null  int32
#  32  SeasonId_2021                                      111991 non-null  int32
#  33  SeasonId_2022                                      111991 non-null  int32
#  34  SeasonId_2023                                      111991 non-null  int32
#  35  Opposition Id_1d6cd83892ee4afdcd8ccd94f817b4a6     111991 non-null  int32
#  36  Opposition Id_1d6cd83892ee4afdcd8ccd94f81ftnjhl3s  111991 non-null  int32
#  37  Opposition Id_367ef61d2bc259e608027a8d349c933e     111991 non-null  int32
#  38  Opposition Id_3b26834df063f9d51de216a07ec36929     111991 non-null  int32
#  39  Opposition Id_58485e3acf60682c8fc37d9d521b3019     111991 non-null  int32
#  40  Opposition Id_5e03a19f4d014a2220665cfd56522d35     111991 non-null  int32
#  41  Opposition Id_837e03d56b4dba3b8a4a5425c0420abd     111991 non-null  int32
#  42  Opposition Id_980c9c368ae4f1129ea0a6fdd711fa8f     111991 non-null  int32
#  43  Opposition Id_a73752d38e4a78e3e14917f5435ffb6d     111991 non-null  int32
#  44  Opposition Id_b53920c88e4eebf2faa9f4fb43b8944a     111991 non-null  int32
#  45  Opposition Id_c03196722c1a837b39f79f1714db475d     111991 non-null  int32
#  46  Opposition Id_c14e0139ad91a9741a5731a596aa6549     111991 non-null  int32
#  47  Opposition Id_d3ac47d424b41fd738ec9500dbda2d59     111991 non-null  int32
#  48  Opposition Id_dc3c7bd8148814b7c4105841baa68e23     111991 non-null  int32
#  49  Opposition Id_f38f7f087f646c38c0207f1b2af32f12     111991 non-null  int32
#  50  Opposition Id_fdfcde48e2cbf12cc4710a2644b86d85     111991 non-null  int32
#  51  Half_2                                             111991 non-null  int32
#  52  Half_3                                             111991 non-null  int32
#  53  Half_4                                             111991 non-null  int32
#  54  PTB Contest_Other                                  111991 non-null  int32
#  55  PTB Contest_Stays on feet                          111991 non-null  int32
#  56  PTB Contest_Tackled to ground                      111991 non-null  int32
#  57  PTB Ultimate Outcome_Field goal attempt            111991 non-null  int32
#  58  PTB Ultimate Outcome_Handover                      111991 non-null  int32
#  59  PTB Ultimate Outcome_Kick                          111991 non-null  int32
#  60  PTB Ultimate Outcome_Opp ruck infringement         111991 non-null  int32
#  61  PTB Ultimate Outcome_Other                         111991 non-null  int32
#  62  PTB Ultimate Outcome_Penalty attack                111991 non-null  int32
#  63  PTB Ultimate Outcome_Penalty defence               111991 non-null  int32
#  64  PTB Ultimate Outcome_Try                           111991 non-null  int32
#  65  PTB Ultimate Outcome_Turnover                      111991 non-null  int32
#  66  OfficialId_500002                                  111991 non-null  int32
#  67  OfficialId_500004                                  111991 non-null  int32
#  68  OfficialId_500006                                  111991 non-null  int32
#  69  OfficialId_500016                                  111991 non-null  int32
#  70  OfficialId_500019                                  111991 non-null  int32
#  71  OfficialId_500029                                  111991 non-null  int32
#  72  OfficialId_500039                                  111991 non-null  int32
#  73  OfficialId_500042                                  111991 non-null  int32
#  74  OfficialId_500045                                  111991 non-null  int32
#  75  OfficialId_500050                                  111991 non-null  int32
#  76  OfficialId_500067                                  111991 non-null  int32
#  77  OfficialId_500070                                  111991 non-null  int32
#  78  OfficialId_500072                                  111991 non-null  int32
#  79  OfficialId_500075                                  111991 non-null  int32
#  80  OfficialId_500117                                  111991 non-null  int32
#  81  Raw Tackle Number_2.0                              111991 non-null  int32
#  82  Raw Tackle Number_3.0                              111991 non-null  int32
#  83  Raw Tackle Number_4.0                              111991 non-null  int32
#  84  Raw Tackle Number_5.0                              111991 non-null  int32
#  85  Raw Tackle Number_6.0                              111991 non-null  int32
#  86  Raw Tackle Number_7.0                              111991 non-null  int32
# dtypes: float64(6), int32(75), int64(6)
# memory usage: 43.1 MB

# %%
# RUNNING OLS WITH TRAIN TEST SPLIT
from sklearn.model_selection import train_test_split
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error, r2_score

Y = df_encoded['DurationSecs']
X = df_encoded.drop(['DurationSecs'],axis = 1)
X = sm.add_constant(X)

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=37)

OLS_model = sm.OLS(Y, X).fit()

y_pred = OLS_model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}" )

r_squared = r2_score(y_test, y_pred)
print(f"R-squared: {r_squared}")
n = X_test.shape[0]  # Number of observations
p = X_test.shape[1]  # Number of features (predictors)
adjusted_r_squared = 1 - (1 - r_squared) * (n - 1) / (n - p - 1)
print(f"Adjusted_r_squared: {adjusted_r_squared}")

print(OLS_model.summary())
# Out:
# Mean Squared Error: 0.9375322225600876
# R-squared: 0.1938670665060519
# Adjusted_r_squared: 0.19072361416353145
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           DurationSecs   R-squared:                       0.192
# Model:                            OLS   Adj. R-squared:                  0.192
# Method:                 Least Squares   F-statistic:                     309.6
# Date:                Mon, 11 Nov 2024   Prob (F-statistic):               0.00
# Time:                        15:46:01   Log-Likelihood:            -1.5594e+05
# No. Observations:              111991   AIC:                         3.121e+05
# Df Residuals:                  111904   BIC:                         3.129e+05
# Df Model:                          86
# Covariance Type:            nonrobust
# =====================================================================================================================
#                                                         coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# const                                                 3.5865      0.028    126.988      0.000       3.531       3.642
# OppPossessionSecs                                     0.0004   5.75e-05      6.841      0.000       0.000       0.001
# PossessionSecs                                        0.0005   5.75e-05      8.938      0.000       0.000       0.001
# Set Type                                              0.1972      0.012     16.715      0.000       0.174       0.220
# Total Involved Tacklers                               0.0482      0.004     11.583      0.000       0.040       0.056
# RoundId                                              -0.0020      0.000     -4.533      0.000      -0.003      -0.001
# RunOn                                                 0.1219      0.008     15.382      0.000       0.106       0.137
# Score                                                 0.0049      0.001      7.256      0.000       0.004       0.006
# SeqNumber                                          -9.02e-05   1.43e-05     -6.300      0.000      -0.000   -6.21e-05
# ZonePossession                                        0.0033      0.000     11.063      0.000       0.003       0.004
# IsHome                                               -0.0322      0.006     -5.346      0.000      -0.044      -0.020
# CurrentMargin                                         0.0008      0.000      1.746      0.081      -0.000       0.002
# WeatherConditionName_Rain                             0.1040      0.022      4.756      0.000       0.061       0.147
# WeatherConditionName_Showers                         -0.0281      0.021     -1.333      0.183      -0.069       0.013
# WeatherConditionName_Snow                            -0.1321      0.044     -3.004      0.003      -0.218      -0.046
# WeatherConditionName_Unknown                          0.0239      0.008      2.861      0.004       0.008       0.040
# Club Id_1d6cd83892ee4afdcd8ccd94f817b4a6              0.0304      0.018      1.687      0.092      -0.005       0.066
# Club Id_1d6cd83892ee4afdcd8ccd94f81ftnjhl3s          -0.0166      0.030     -0.558      0.577      -0.075       0.042
# Club Id_367ef61d2bc259e608027a8d349c933e             -0.1275      0.019     -6.706      0.000      -0.165      -0.090
# Club Id_3b26834df063f9d51de216a07ec36929              0.0739      0.018      4.100      0.000       0.039       0.109
# Club Id_58485e3acf60682c8fc37d9d521b3019              0.0662      0.019      3.546      0.000       0.030       0.103
# Club Id_5e03a19f4d014a2220665cfd56522d35              0.0018      0.018      0.100      0.920      -0.034       0.038
# Club Id_837e03d56b4dba3b8a4a5425c0420abd             -0.0335      0.018     -1.865      0.062      -0.069       0.002
# Club Id_980c9c368ae4f1129ea0a6fdd711fa8f             -0.0381      0.018     -2.073      0.038      -0.074      -0.002
# Club Id_a73752d38e4a78e3e14917f5435ffb6d              0.1262      0.018      6.982      0.000       0.091       0.162
# Club Id_b53920c88e4eebf2faa9f4fb43b8944a              0.0891      0.018      4.864      0.000       0.053       0.125
# Club Id_c03196722c1a837b39f79f1714db475d             -0.0793      0.018     -4.394      0.000      -0.115      -0.044
# Club Id_c14e0139ad91a9741a5731a596aa6549              0.1127      0.019      6.061      0.000       0.076       0.149
# Club Id_d3ac47d424b41fd738ec9500dbda2d59             -0.0119      0.018     -0.652      0.515      -0.048       0.024
# Club Id_dc3c7bd8148814b7c4105841baa68e23             -0.0716      0.018     -3.976      0.000      -0.107      -0.036
# Club Id_f38f7f087f646c38c0207f1b2af32f12             -0.0999      0.018     -5.452      0.000      -0.136      -0.064
# Club Id_fdfcde48e2cbf12cc4710a2644b86d85             -0.0497      0.018     -2.697      0.007      -0.086      -0.014
# SeasonId_2021                                         0.1787      0.009     19.450      0.000       0.161       0.197
# SeasonId_2022                                         0.2446      0.010     23.499      0.000       0.224       0.265
# SeasonId_2023                                         0.1893      0.010     18.203      0.000       0.169       0.210
# Opposition Id_1d6cd83892ee4afdcd8ccd94f817b4a6        0.0066      0.018      0.366      0.714      -0.029       0.042
# Opposition Id_1d6cd83892ee4afdcd8ccd94f81ftnjhl3s    -0.2970      0.029    -10.129      0.000      -0.354      -0.239
# Opposition Id_367ef61d2bc259e608027a8d349c933e       -0.0203      0.019     -1.066      0.287      -0.058       0.017
# Opposition Id_3b26834df063f9d51de216a07ec36929       -0.1011      0.018     -5.555      0.000      -0.137      -0.065
# Opposition Id_58485e3acf60682c8fc37d9d521b3019       -0.0165      0.019     -0.886      0.376      -0.053       0.020
# Opposition Id_5e03a19f4d014a2220665cfd56522d35       -0.0717      0.018     -3.918      0.000      -0.108      -0.036
# Opposition Id_837e03d56b4dba3b8a4a5425c0420abd       -0.1189      0.018     -6.637      0.000      -0.154      -0.084
# Opposition Id_980c9c368ae4f1129ea0a6fdd711fa8f       -0.0821      0.018     -4.478      0.000      -0.118      -0.046
# Opposition Id_a73752d38e4a78e3e14917f5435ffb6d       -0.0929      0.018     -5.105      0.000      -0.129      -0.057
# Opposition Id_b53920c88e4eebf2faa9f4fb43b8944a       -0.0323      0.018     -1.778      0.075      -0.068       0.003
# Opposition Id_c03196722c1a837b39f79f1714db475d       -0.1144      0.018     -6.283      0.000      -0.150      -0.079
# Opposition Id_c14e0139ad91a9741a5731a596aa6549        0.0594      0.019      3.151      0.002       0.022       0.096
# Opposition Id_d3ac47d424b41fd738ec9500dbda2d59       -0.0522      0.019     -2.806      0.005      -0.089      -0.016
# Opposition Id_dc3c7bd8148814b7c4105841baa68e23        0.0066      0.018      0.370      0.712      -0.029       0.042
# Opposition Id_f38f7f087f646c38c0207f1b2af32f12        0.0159      0.018      0.867      0.386      -0.020       0.052
# Opposition Id_fdfcde48e2cbf12cc4710a2644b86d85       -0.1229      0.018     -6.719      0.000      -0.159      -0.087
# Half_2                                               -0.0941      0.012     -8.123      0.000      -0.117      -0.071
# Half_3                                               -0.4569      0.065     -6.980      0.000      -0.585      -0.329
# Half_4                                               -0.4772      0.092     -5.174      0.000      -0.658      -0.296
# PTB Contest_Other                                    -0.5317      0.398     -1.336      0.182      -1.312       0.248
# PTB Contest_Stays on feet                            -1.1141      0.013    -84.046      0.000      -1.140      -1.088
# PTB Contest_Tackled to ground                        -0.7351      0.006   -119.676      0.000      -0.747      -0.723
# PTB Ultimate Outcome_Field goal attempt              -0.2691      0.130     -2.077      0.038      -0.523      -0.015
# PTB Ultimate Outcome_Handover                        -0.0528      0.036     -1.471      0.141      -0.123       0.018
# PTB Ultimate Outcome_Kick                            -0.0152      0.012     -1.281      0.200      -0.038       0.008
# PTB Ultimate Outcome_Opp ruck infringement            0.0225      0.023      0.958      0.338      -0.024       0.068
# PTB Ultimate Outcome_Other                           -0.0510      0.098     -0.519      0.604      -0.243       0.141
# PTB Ultimate Outcome_Penalty attack                   0.0380      0.038      1.010      0.312      -0.036       0.112
# PTB Ultimate Outcome_Penalty defence                 -0.0495      0.038     -1.288      0.198      -0.125       0.026
# PTB Ultimate Outcome_Try                             -0.0106      0.020     -0.540      0.589      -0.049       0.028
# PTB Ultimate Outcome_Turnover                        -0.0301      0.015     -2.028      0.043      -0.059      -0.001
# OfficialId_500002                                    -0.0213      0.016     -1.302      0.193      -0.053       0.011
# OfficialId_500004                                    -0.0244      0.014     -1.688      0.091      -0.053       0.004
# OfficialId_500006                                     0.0151      0.023      0.661      0.508      -0.030       0.060
# OfficialId_500016                                    -0.0507      0.014     -3.590      0.000      -0.078      -0.023
# OfficialId_500019                                    -0.0508      0.014     -3.631      0.000      -0.078      -0.023
# OfficialId_500029                                    -0.0613      0.016     -3.911      0.000      -0.092      -0.031
# OfficialId_500039                                    -0.0832      0.014     -5.914      0.000      -0.111      -0.056
# OfficialId_500042                                    -0.0429      0.023     -1.870      0.061      -0.088       0.002
# OfficialId_500045                                    -0.0419      0.047     -0.884      0.377      -0.135       0.051
# OfficialId_500050                                    -0.0115      0.015     -0.759      0.448      -0.041       0.018
# OfficialId_500067                                    -0.0661      0.015     -4.493      0.000      -0.095      -0.037
# OfficialId_500070                                    -0.0341      0.043     -0.795      0.426      -0.118       0.050
# OfficialId_500072                                     0.0632      0.064      0.979      0.327      -0.063       0.190
# OfficialId_500075                                    -0.0667      0.024     -2.749      0.006      -0.114      -0.019
# OfficialId_500117                                    -0.0503      0.017     -3.018      0.003      -0.083      -0.018
# Raw Tackle Number_2.0                                -0.2259      0.009    -26.240      0.000      -0.243      -0.209
# Raw Tackle Number_3.0                                -0.3160      0.009    -33.999      0.000      -0.334      -0.298
# Raw Tackle Number_4.0                                -0.3555      0.010    -33.934      0.000      -0.376      -0.335
# Raw Tackle Number_5.0                                -0.3985      0.015    -26.443      0.000      -0.428      -0.369
# Raw Tackle Number_6.0                                -0.2890      0.029     -9.943      0.000      -0.346      -0.232
# Raw Tackle Number_7.0                                -0.3079      0.256     -1.202      0.229      -0.810       0.194
# ==============================================================================
# Omnibus:                    15983.510   Durbin-Watson:                   1.864
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           104543.839
# Skew:                           0.519   Prob(JB):                         0.00
# Kurtosis:                       7.618   Cond. No.                     9.98e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.98e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# RUNNING OLS WITH CROSS-VALIDATION

from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import make_scorer, mean_squared_error
import statsmodels.api as sm

Y = df_encoded['DurationSecs']
X = df_encoded.drop(['DurationSecs'],axis = 1)
X = sm.add_constant(X)

ols_model = LinearRegression()

# Perform cross-validation and get MSE scores
cv_mses = -1 * cross_val_score(ols_model, X, Y, cv=5, scoring='neg_mean_squared_error')  # 5-fold cross-validation

cv_mse = cv_mses.mean()

print("Cross-Validation MSE:", cv_mse)
# Out:
# Cross-Validation MSE: 0.9755223651529871

# %%
# JOINT F TESTS FOR CATEGORICAL FEATURES:

# Add a constant to the independent variables
X_full = sm.add_constant(X)
X_restricted = sm.add_constant(X.loc[:, ~X.columns.str.startswith('OfficialId')])

# Fit the modelshow c
model_full = sm.OLS(df_encoded['DurationSecs'], X_full).fit()
model_restricted = sm.OLS(df_encoded['DurationSecs'], X_restricted).fit()

# Perform the F-test to compare the models
f_test = model_full.compare_f_test(model_restricted)

# Results
print("F-statistic:", f_test[0])
print("p-value:", f_test[1])
# Out:
# F-statistic: 5.47439280158252
# p-value: 2.890888194038193e-11

# %%
from sklearn.linear_model import LassoCV, Lasso
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

y = df_encoded['DurationSecs']
X = df_encoded.drop(['DurationSecs'],axis = 1)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=37)

lasso_cv = LassoCV(cv=5, max_iter=100000).fit(X_train, y_train)
print("Optimal alpha:", lasso_cv.alpha_)

lasso_best = Lasso(alpha=lasso_cv.alpha_)
lasso_best.fit(X_train, y_train)


y_pred = lasso_best.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
print(f"Mean Absolute Error: {mae}")


mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}" )


r_squared = r2_score(y_test, y_pred)
print(f"R-squared: {r_squared}")
n = X_test.shape[0]  # Number of observations
p = X_test.shape[1]  # Number of features (predictors)
adjusted_r_squared = 1 - (1 - r_squared) * (n - 1) / (n - p - 1)
print(f"Adjusted_r_squared: {adjusted_r_squared}")

pd.set_option('display.max_rows', None)

lasso_coefficients = pd.Series(lasso_best.coef_, index=X.columns)
print(lasso_coefficients)
# Out:
# Optimal alpha: 0.0003143152902245518
# Mean Absolute Error: 0.7156416804058044
# Mean Squared Error: 0.9196891223360028
# R-squared: 0.19223661681387516
# Adjusted_r_squared: 0.18919569339758713
# OppPossessionSecs                                    0.122882
# Player Id                                            0.004062
# PositionId                                          -0.048661
# PossessionSecs                                       0.175134
# Set Type                                             0.084324
# Total Involved Tacklers                              0.034675
# Raw Tackle Number                                   -0.138175
# RoundId                                             -0.015485
# RunOn                                                0.019533
# Score                                                0.028286
# SeasonId                                             0.060310
# SeqNumber                                           -0.274618
# Set                                                 -0.024785
# ZonePossession                                       0.072666
# GameTime                                             0.063210
# IsHome                                              -0.015361
# CurrentMargin                                        0.007980
# currMargin_gameTime_interaction                      0.017971
# WeatherConditionName_Rain                            0.012318
# WeatherConditionName_Showers                        -0.004229
# WeatherConditionName_Snow                           -0.002637
# WeatherConditionName_Unknown                         0.012488
# Club Id_1d6cd83892ee4afdcd8ccd94f817b4a6             0.003061
# Club Id_1d6cd83892ee4afdcd8ccd94f81ftnjhl3s         -0.008131
# Club Id_367ef61d2bc259e608027a8d349c933e            -0.034875
# Club Id_3b26834df063f9d51de216a07ec36929             0.020686
# Club Id_58485e3acf60682c8fc37d9d521b3019             0.015122
# Club Id_5e03a19f4d014a2220665cfd56522d35             0.000000
# Club Id_837e03d56b4dba3b8a4a5425c0420abd            -0.007252
# Club Id_980c9c368ae4f1129ea0a6fdd711fa8f            -0.009533
# Club Id_a73752d38e4a78e3e14917f5435ffb6d             0.031542
# Club Id_b53920c88e4eebf2faa9f4fb43b8944a             0.023130
# Club Id_c03196722c1a837b39f79f1714db475d            -0.020817
# Club Id_c14e0139ad91a9741a5731a596aa6549             0.019102
# Club Id_d3ac47d424b41fd738ec9500dbda2d59            -0.006001
# Club Id_dc3c7bd8148814b7c4105841baa68e23            -0.015786
# Club Id_f38f7f087f646c38c0207f1b2af32f12            -0.026572
# Club Id_fdfcde48e2cbf12cc4710a2644b86d85            -0.010150
# Opposition Id_1d6cd83892ee4afdcd8ccd94f817b4a6       0.000623
# Opposition Id_1d6cd83892ee4afdcd8ccd94f81ftnjhl3s   -0.040514
# Opposition Id_367ef61d2bc259e608027a8d349c933e      -0.007586
# Opposition Id_3b26834df063f9d51de216a07ec36929      -0.023426
# Opposition Id_58485e3acf60682c8fc37d9d521b3019      -0.006320
# Opposition Id_5e03a19f4d014a2220665cfd56522d35      -0.018689
# Opposition Id_837e03d56b4dba3b8a4a5425c0420abd      -0.027650
# Opposition Id_980c9c368ae4f1129ea0a6fdd711fa8f      -0.020335
# Opposition Id_a73752d38e4a78e3e14917f5435ffb6d      -0.023712
# Opposition Id_b53920c88e4eebf2faa9f4fb43b8944a      -0.002744
# Opposition Id_c03196722c1a837b39f79f1714db475d      -0.027735
# Opposition Id_c14e0139ad91a9741a5731a596aa6549       0.010579
# Opposition Id_d3ac47d424b41fd738ec9500dbda2d59      -0.013043
# Opposition Id_dc3c7bd8148814b7c4105841baa68e23       0.003435
# Opposition Id_f38f7f087f646c38c0207f1b2af32f12       0.001996
# Opposition Id_fdfcde48e2cbf12cc4710a2644b86d85      -0.026792
# Half_2                                               0.061456
# Half_3                                              -0.000000
# Half_4                                              -0.000000
# PTB Contest_Other                                   -0.003802
# PTB Contest_Stays on feet                           -0.252277
# PTB Contest_Tackled to ground                       -0.366051
# PTB Ultimate Outcome_Field goal attempt             -0.005549
# PTB Ultimate Outcome_Handover                        0.004860
# PTB Ultimate Outcome_Kick                            0.020713
# PTB Ultimate Outcome_Opp ruck infringement           0.001527
# PTB Ultimate Outcome_Other                           0.002804
# PTB Ultimate Outcome_Penalty attack                  0.010690
# PTB Ultimate Outcome_Penalty defence                -0.003125
# PTB Ultimate Outcome_Try                             0.001658
# PTB Ultimate Outcome_Turnover                       -0.004568
# OfficialId_500002                                   -0.007081
# OfficialId_500004                                   -0.011450
# OfficialId_500006                                   -0.011632
# OfficialId_500016                                   -0.022860
# OfficialId_500019                                   -0.015595
# OfficialId_500029                                   -0.019859
# OfficialId_500039                                   -0.031208
# OfficialId_500042                                   -0.013866
# OfficialId_500045                                   -0.007888
# OfficialId_500050                                   -0.003819
# OfficialId_500067                                   -0.016784
# OfficialId_500070                                    0.002175
# OfficialId_500072                                   -0.000000
# OfficialId_500075                                   -0.006338
# OfficialId_500117                                   -0.013652
# dtype: float64
# C:\Users\irvin\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.607e+01, tolerance: 1.060e+01
#   model = cd_fast.enet_coordinate_descent(
